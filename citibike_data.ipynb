# %%
import pandas as pd
path="./raw_data/"

# %%
df1= pd.read_csv(path+ "201902-citibike-tripdata.csv")
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1           143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2           296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3           478  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4           225  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
df2 = pd.read_csv(path+ "201904-citibike-tripdata.csv")
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0            88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1           443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2           662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3            86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4           136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
#
#    start station id      start station name  start station latitude  \
# 0              2006  Central Park S & 6 Ave               40.765909
# 1               254         W 11 St & 6 Ave               40.735324
# 2              3244  University Pl & E 8 St               40.731437
# 3               526         E 33 St & 5 Ave               40.747659
# 4               461         E 20 St & 2 Ave               40.735877
#
#    start station longitude  end station id         end station name  \
# 0               -73.976342            2006   Central Park S & 6 Ave
# ...

# %%
df3 = pd.read_csv(path+ "201908-citibike-tripdata.csv")
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# ...

# %%
joint = [df1,df2,df3]
df = pd.concat(joint).drop_duplicates()

# %%
df.shape
# Out:
# (5054062, 15)

# %%
row1 = df.sample(n = 1)
row1
# Out:
#         tripduration                 starttime                  stoptime  \
# 790701           452  2019-04-13 19:15:18.7800  2019-04-13 19:22:51.3330
#
#         start station id       start station name  start station latitude  \
# 790701             471.0  Grand St & Havemeyer St               40.712868
#
#         start station longitude  end station id    end station name  \
# 790701               -73.956981           460.0  S 4 St & Wythe Ave
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 790701             40.712859             -73.965903   32349  Subscriber
#
#         birth year  gender
# 790701        1993       2

# %%
df.to_csv(path + "phemone2019.csv", index = False)

# %%
df = pd.read_csv(path + "phemone2019.csv")

# %%
df.tail()
# Out:
#          tripduration                 starttime                  stoptime  \
# 5054057           216  2019-08-31 23:59:46.2930  2019-09-01 00:03:23.0360
# 5054058           117  2019-08-31 23:59:47.7970  2019-09-01 00:01:45.7440
# 5054059          1614  2019-08-31 23:59:48.1560  2019-09-01 00:26:42.7760
# 5054060          1301  2019-08-31 23:59:58.3620  2019-09-01 00:21:39.7040
# 5054061           419  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id           start station name  \
# 5054057             116.0              W 17 St & 8 Ave
# 5054058            3429.0       Hanson Pl & Ashland Pl
# 5054059             387.0      Centre St & Chambers St
# 5054060            3168.0  Central Park West & W 85 St
# 5054061             447.0              8 Ave & W 52 St
#
#          start station latitude  start station longitude  end station id  \
# 5054057               40.741776               -74.001497           509.0
# ...

# %%
df = df.loc[((df["tripduration"]>90) & (df["start station id"] != df["end station id"])),:]
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1           143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2           296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3           478  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4           225  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
df["tripduration"] = [trip/60 for trip in df["tripduration"]]
df = df.loc[df["tripduration"] < 1440, :]
df.rename(columns={"tripduration":"tripduration (min)"})
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.650000  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1      2.383333  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2      4.933333  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3      7.966667  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4      3.750000  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
gender = {0:"Unknown", 1:"Male", 2:"Female"}
df.gender = [gender[item] for item in df.gender]
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.650000  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1      2.383333  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2      4.933333  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3      7.966667  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4      3.750000  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
from math import sin, cos, sqrt, atan2, radians

# Convert degrees to radians
lat1 = [radians(lat) for lat in df["start station latitude"]]
lon1 = [radians(lon) for lon in df["start station longitude"]]
lat2 = [radians(lat) for lat in df["end station latitude"]]
lon2 = [radians(lon) for lon in df["end station longitude"]]

# Convert lists into series
lat1 = pd.Series(lat1)
lon1 = pd.Series(lon1)
lat2 = pd.Series(lat2)
lon2 = pd.Series(lon2)

# Calculate difference between each set of latitude and longitude
dlat = lat2 - lat1
dlon = lon2 - lon1

# %%
R = 6373.0

# Empty list to store trip distances
distance = []

for i in range(0, len(lat1)):
    
    a = sin(dlat[i] / 2)**2 + cos(lat1[i]) * cos(lat2[i]) * sin(dlon[i] / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    # Get distance and convert km to miles
    miles = (R * c) * .6214
    
    # Append miles travel to 'distance' list
    distance.append(miles)

# %%
df["tripdistance (mi)"] = distance
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      3.650000  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1      2.383333  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2      4.933333  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3      7.966667  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4      3.750000  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
#
#    start station id        start station name  start station latitude  \
# 0            3494.0  E 115 St & Lexington Ave               40.797911
# 1             438.0       St Marks Pl & 1 Ave               40.727791
# 2            3571.0   Bedford Ave & Bergen St               40.676368
# 3             167.0           E 39 St & 3 Ave               40.748901
# 4            3458.0           W 55 St & 6 Ave               40.763094
#
#    start station longitude  end station id        end station name  \
# ...

# %%
ages = []

for i in df["birth year"]:
    age = 2020 - i
    ages.append(age)

# %%
df["Age"] = ages
df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0            3.650000  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1            2.383333  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2            4.933333  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3            7.966667  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4            3.750000  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
# ...               ...                       ...                       ...
# 5054057      3.600000  2019-08-31 23:59:46.2930  2019-09-01 00:03:23.0360
# 5054058      1.950000  2019-08-31 23:59:47.7970  2019-09-01 00:01:45.7440
# 5054059     26.900000  2019-08-31 23:59:48.1560  2019-09-01 00:26:42.7760
# 5054060     21.683333  2019-08-31 23:59:58.3620  2019-09-01 00:21:39.7040
# 5054061      6.983333  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id           start station name  \
# ...

# %%
df = df.loc[df["Age"] < 90]

# %%
bins = [0, 17, 25, 35, 50, 65, 90]
labels = ["0-17", "18-25", "26-35", "36-50", "51-65", "65-90"]

df["Age Group"] = pd.cut(df["Age"], bins, labels=labels)
# Out:
# <ipython-input-76-41e879585343>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age Group"] = pd.cut(df["Age"], bins, labels=labels)

# %%
del df["birth year"]

# %%
df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0            3.650000  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1            2.383333  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2            4.933333  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3            7.966667  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4            3.750000  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
# ...               ...                       ...                       ...
# 5054057      3.600000  2019-08-31 23:59:46.2930  2019-09-01 00:03:23.0360
# 5054058      1.950000  2019-08-31 23:59:47.7970  2019-09-01 00:01:45.7440
# 5054059     26.900000  2019-08-31 23:59:48.1560  2019-09-01 00:26:42.7760
# 5054060     21.683333  2019-08-31 23:59:58.3620  2019-09-01 00:21:39.7040
# 5054061      6.983333  2019-08-31 23:59:59.4520  2019-09-01 00:06:59.0210
#
#          start station id           start station name  \
# ...

# %%
df.to_csv(path + "datacleaned2019.csv", index = False)

# %%
df['starttime'] = df['starttime'].astype('str')
mask = df['starttime'].str.len() != 7
df2 = df.loc[mask]
df2.shape
# Out:
# <ipython-input-79-97cee10ee5a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['starttime'] = df['starttime'].astype('str')
# (4910190, 17)

# %%
import datetime

df['startMonth']=pd.DatetimeIndex(df['starttime']).month
df['startMonth'].head()
# Out:
# <ipython-input-80-f1f134ad7c94>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['startMonth']=pd.DatetimeIndex(df['starttime']).month
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: startMonth, dtype: int64

# %%
df["startMonth"].tail()
# Out:
# 5054057    8
# 5054058    8
# 5054059    8
# 5054060    8
# 5054061    8
# Name: startMonth, dtype: int64

# %%
df["startMonth"].value_counts()
# Out:
# 8    2274035
# 4    1714679
# 2     921476
# Name: startMonth, dtype: int64

# %%
df.to_csv(path + "phemonecleaned2019.csv", index = False)
